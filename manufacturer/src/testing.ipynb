# %%
import sys
# print(sys.path)
print(sys.modules.get('manufacturer'))
print(sys.modules.get('manufacturer.schema'))
sys.modules.pop('manufacturer',None)
sys.modules.pop('manufacturer.schema',None)

# %%
from manufacturer import get_schema
get_schema("distributor")
